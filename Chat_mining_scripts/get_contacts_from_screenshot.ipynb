# %% [markdown]
# OCR to extract numbers from images:

# %%
import cv2
import pytesseract
from tqdm import tqdm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import cv2
#       2 import pytesseract
#       3 from tqdm import tqdm
#
# ModuleNotFoundError: No module named 'cv2'

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 23 not upgraded.
# Need to get 4,850 kB of archives.
# After this operation, 16.3 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 tesseract-ocr-eng all 1:4.00~git30-7274cfa-1 [1,598 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 tesseract-ocr-osd all 1:4.00~git30-7274cfa-1 [2,990 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/universe amd64 tesseract-ocr amd64 4.1.1-2build2 [262 kB]
# Fetched 4,850 kB in 1s (4,328 kB/s)
# debconf: unable to initialize frontend: Dialog
# ...

# %%
import zipfile
# if the pictures are in a zip file
zip_file = zipfile.ZipFile("/content/playo contacts-20230325T105358Z-001.zip", "r")
zip_file.extractall()
zip_file.close()

# %%
# Load the image

def read_image(code):
  image_name="/content/playo contacts/IMG-20230219-WA00"+ str(code) + ".jpg"
  img = cv2.imread(image_name)

  # Convert the image to grayscale
  gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

  # Apply Otsu's thresholding method
  thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

  # Run Tesseract OCR on the image
  text = pytesseract.image_to_string(thresh, lang="eng")
  return text

# %%
phone_numbers=[]
for iter in tqdm(range(41,85)):
  text=read_image(iter)
  all_list=text.split("\n")
  for i in all_list:
    if(i!=''):
      if(i[0]=='+'):
        phone_numbers.append(i)
print(phone_numbers)
# Out:
# 100%|██████████| 44/44 [01:00<00:00,  1.37s/it]
# ...

# %%
all_list=text.split("\n")
phone_numbers=[]
for i in all_list:
  if(i!=''):
    if(i[0]=='+'):
      phone_numbers.append(i)
print(phone_numbers)
# Out:
# ['+91 83760 13414', '+91 84330 67269', '+91 84472 09273', '+91 84473 43530', '+91 85002 66033', '+91 85100 70666', '+91 85270 60950', '+91 85350 78289', '+91 85728 59170', '+91 85880 43758', '+91 85888 62409']

# %%
# convert the set to the list
unique_list = list(set(phone_numbers))
len(unique_list)
# Out:
# 443

# %%
from google.colab import  drive
drive.mount('/drive')
with open('/drive/My Drive/foo.csv', 'w') as f:
  o.to_csv(f)
